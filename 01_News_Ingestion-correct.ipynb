# %%
from datetime import datetime
import pandas as pd
import requests

print("=" * 60)
print("AI Financial Market Intelligence Project")
print("=" * 60)
print(f"Project Started: {datetime.now()}")
print("Lakehouse Connected Successfully")
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 3, Finished, Available, Finished, False)
# ============================================================
# AI Financial Market Intelligence Project
# ============================================================
# Project Started: 2026-07-16 13:57:16.463408
# Lakehouse Connected Successfully

# %%
portfolio_tickers = [
    "NVDA",
    "META",
    "AMD",
    "AAPL",
    "AMZN",
    "GOOGL",
    "IBM",
    "SOFI",
    "TSLA",
    "PLTR",
    "RGTI",
    "NFLX",
    "MCD",
    "NKE",
    "SHEL",
    "NOK"
]

print(f"Monitoring {len(portfolio_tickers)} stocks:")
print(portfolio_tickers)
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 4, Finished, Available, Finished, False)
# Monitoring 16 stocks:
# ['NVDA', 'META', 'AMD', 'AAPL', 'AMZN', 'GOOGL', 'IBM', 'SOFI', 'TSLA', 'PLTR', 'RGTI', 'NFLX', 'MCD', 'NKE', 'SHEL', 'NOK']

# %%
from datetime import datetime, timedelta, timezone
import requests
import pandas as pd
import time

FINNHUB_API_KEY = "d9ce9ipr01qmn1jh83t0d9ce9ipr01qmn1jh83tg"

# We begin with 7 days so we have enough articles for testing.
date_to = datetime.now(timezone.utc).date()
date_from = date_to - timedelta(days=7)

print("News period:", date_from, "to", date_to)
print("Tickers:", len(portfolio_tickers))
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 6, Finished, Available, Finished, False)
# News period: 2026-07-09 to 2026-07-16
# Tickers: 16

# %%
test_ticker = "NVDA"

url = "https://finnhub.io/api/v1/company-news"

params = {
    "symbol": test_ticker,
    "from": str(date_from),
    "to": str(date_to),
    "token": FINNHUB_API_KEY
}

response = requests.get(
    url,
    params=params,
    timeout=30
)

print("HTTP status:", response.status_code)

response.raise_for_status()

test_news = response.json()

print("Articles returned:", len(test_news))
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 7, Finished, Available, Finished, False)
# HTTP status: 200
# Articles returned: 250

# %%
if len(test_news) > 0:
    for article in test_news[:5]:
        print("=" * 90)
        print("Headline:", article.get("headline"))
        print("Source:", article.get("source"))
        print("URL:", article.get("url"))
        print("Published timestamp:", article.get("datetime"))
else:
    print("No NVIDIA articles were returned for the selected period.")
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 8, Finished, Available, Finished, False)
# ==========================================================================================
# Headline: Dow Jones Futures Rise But AI Woes Continue; Taiwan Semi, GE, UnitedHealth Are Key Earnings Movers
# Source: Yahoo
# URL: https://finnhub.io/api/news?id=759627f5149f28b6538283c3bf9a71edb694c1f7d5a2529b6c8f3576feb62f51
# Published timestamp: 1784202482
# ==========================================================================================
# Headline: Micron's Biggest Rival Just Got a Lot Easier for US Investors to Own
# Source: Yahoo
# URL: https://finnhub.io/api/news?id=b014e14cbd6ed5950ac35e763917fc6cd180ee13c4821a0f458a716c8ed5c3e7
# Published timestamp: 1784202180
# ==========================================================================================
# Headline: 3 "Magnificent Seven" Stocks Worth Buying Right Now
# Source: Yahoo
# URL: https://finnhub.io/api/news?id=e4860f9cb414df4cbdc072c62d9bd210cb5bc4865542684ba63210fa183cd5c7
# Published timestamp: 1784201520
# ==========================================================================================
# Headline: TSMC raises capex and revenue forecast, highlighting growing AI chip demand
# Source: Yahoo
# URL: https://finnhub.io/api/news?id=6df266bd73d2c863ee2d0ee9f39130530cf384c3e7ff3de02ed5a3644f9b4cac
# Published timestamp: 1784201461
# ==========================================================================================
# Headline: There Are 300 Ultra-High-Yield Dividend Stocks on Wall Street -- but These 2 Are Arguably the Safest of the Bunch
# Source: Yahoo
# URL: https://finnhub.io/api/news?id=a1fe374c8458aa61d7321cb3f985a938d62759f1a6865b02a205d4eddce60aca
# Published timestamp: 1784201160

# %%
nvda_test_df = pd.DataFrame(test_news)

print("Rows:", len(nvda_test_df))
print("Columns:", list(nvda_test_df.columns))

display(nvda_test_df.head(10))
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 10, Finished, Available, Finished, False)
# Rows: 250
# Columns: ['category', 'datetime', 'headline', 'id', 'image', 'related', 'source', 'summary', 'url']
# SynapseWidget(Synapse.DataFrame, 2eb2fa22-7078-4e91-9548-7779a3baf3d7)

# %%
nvda_test_df["Published_Date"] = pd.to_datetime(
    nvda_test_df["datetime"],
    unit="s"
)

display(
    nvda_test_df[
        [
            "Published_Date",
            "related",
            "headline",
            "source",
            "summary"
        ]
    ].head(10)
)
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 12, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 95ffa11c-c71f-4bd7-99b6-26ff7ae60ef9)

# %%
print(nvda_test_df.info())
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 13, Finished, Available, Finished, False)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   category        250 non-null    object
#  1   datetime        250 non-null    int64
#  2   headline        250 non-null    object
#  3   id              250 non-null    int64
#  4   image           250 non-null    object
#  5   related         250 non-null    object
#  6   source          250 non-null    object
#  7   summary         250 non-null    object
#  8   url             250 non-null    object
#  9   Published_Date  250 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(7)
# memory usage: 19.7+ KB
# None

# %%
print("Total Articles:", len(nvda_test_df))
print("Unique IDs:", nvda_test_df["id"].nunique())
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 14, Finished, Available, Finished, False)
# Total Articles: 250
# Unique IDs: 250

# %%
def get_company_news(ticker, date_from, date_to, api_key):
    """
    Download company news for one ticker from Finnhub.
    """

    url = "https://finnhub.io/api/v1/company-news"

    params = {
        "symbol": ticker,
        "from": str(date_from),
        "to": str(date_to),
        "token": api_key
    }

    response = requests.get(url, params=params, timeout=30)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error downloading {ticker}: {response.status_code}")
        return []
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 17, Finished, Available, Finished, False)

# %%
all_news = []

for ticker in portfolio_tickers:

    print(f"Downloading {ticker}...")

    news = get_company_news(
        ticker,
        date_from,
        date_to,
        FINNHUB_API_KEY
    )

    for article in news:

        article["Ticker"] = ticker

        all_news.append(article)

print()
print("="*60)
print("Download completed!")
print("Total Articles:", len(all_news))
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 18, Finished, Available, Finished, False)
# Downloading NVDA...
# Downloading META...
# Downloading AMD...
# Downloading AAPL...
# Downloading AMZN...
# Downloading GOOGL...
# Downloading IBM...
# Downloading SOFI...
# Downloading TSLA...
# Downloading PLTR...
# Downloading RGTI...
# Downloading NFLX...
# Downloading MCD...
# Downloading NKE...
# Downloading SHEL...
# Downloading NOK...
#
# ============================================================
# Download completed!
# Total Articles: 2359

# %%
news_df = pd.DataFrame(all_news)

print(news_df.shape)

display(news_df.head())
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 20, Finished, Available, Finished, False)
# (2359, 10)
# SynapseWidget(Synapse.DataFrame, 9beee3e5-68cd-41d4-a9a8-be032ac45147)

# %%
news_df["datetime"] = pd.to_datetime(
    news_df["datetime"],
    unit="s",
    utc=True
)

news_df = news_df.rename(columns={
    "related": "Related"
})

news_df = news_df[
    [
        "datetime",
        "Ticker",
        "headline",
        "summary",
        "source",
        "url",
        "image",
        "category",
        "id"
    ]
]

display(news_df.head())
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 23, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 7d3e0106-a51d-4dc3-a628-ffe40803a64a)

# %%
before = len(news_df)

news_df = news_df.drop_duplicates(subset=["id"])

after = len(news_df)

print("Before:", before)
print("After :", after)
print("Removed:", before - after)
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 25, Finished, Available, Finished, False)
# Before: 2359
# After : 1835
# Removed: 524

# %%
print(news_df.info())

display(news_df.sample(10))
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 26, Finished, Available, Finished, False)
# <class 'pandas.core.frame.DataFrame'>
# Index: 1835 entries, 0 to 2358
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  1835 non-null   datetime64[ns, UTC]
#  1   Ticker    1835 non-null   object
#  2   headline  1835 non-null   object
#  3   summary   1835 non-null   object
#  4   source    1835 non-null   object
#  5   url       1835 non-null   object
#  6   image     1835 non-null   object
#  7   category  1835 non-null   object
#  8   id        1835 non-null   int64
# dtypes: datetime64[ns, UTC](1), int64(1), object(7)
# memory usage: 143.4+ KB
# None
# SynapseWidget(Synapse.DataFrame, cfec8e05-77a9-4f23-8ec2-04f35a5e2d2f)

# %%
spark_news_df = spark.createDataFrame(news_df)

print("Rows:", spark_news_df.count())

display(spark_news_df.limit(10))
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 27, Finished, Available, Finished, False)
# Rows: 1835
# SynapseWidget(Synapse.DataFrame, f216f83d-5c61-4f0f-a9fa-0488ed73aa5e)

# %%
(
    spark_news_df
        .write
        .mode("overwrite")
        .format("delta")
        .saveAsTable("financial_news_raw")
)
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 28, Finished, Available, Finished, False)

# %%
display(
    spark.table("financial_news_raw")
)

# %%
raw_count = spark.table("financial_news_raw").count()

print("Rows saved in financial_news_raw:", raw_count)
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 31, Finished, Available, Finished, False)
# Rows saved in financial_news_raw: 1835

# %%
display(
    spark.sql("""
        SELECT
            Ticker,
            COUNT(*) AS Article_Count,
            MIN(datetime) AS Oldest_Article,
            MAX(datetime) AS Latest_Article
        FROM financial_news_raw
        GROUP BY Ticker
        ORDER BY Article_Count DESC
    """)
)
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 32, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 1225ec81-3afd-4758-a23d-887f4c0ae9d4)

# %%
ticker_count = spark.sql("""
    SELECT COUNT(DISTINCT Ticker) AS Ticker_Count
    FROM financial_news_raw
""").first()["Ticker_Count"]

print("Distinct tickers stored:", ticker_count)
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 33, Finished, Available, Finished, False)
# Distinct tickers stored: 16

# %%
display(
    spark.sql("""
        SELECT
            COUNT(*) AS Total_Rows,
            COUNT(DISTINCT id) AS Unique_Article_IDs,
            COUNT(*) - COUNT(DISTINCT id) AS Duplicate_Rows
        FROM financial_news_raw
    """)
)
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 34, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, e43d44f7-1c80-47ac-b8bc-84c33f2ab43a)

# %%
print("=" * 70)
print("NEWS INGESTION COMPLETED SUCCESSFULLY")
print("=" * 70)
print(f"Rows stored: {raw_count}")
print(f"Tickers stored: {ticker_count}")
print("Output table: financial_news_raw")
print("Lakehouse: AI_Financial_Lakehouse")
# Out:
# StatementMeta(, 9cf16030-1ea3-4985-b50e-a8991d5c34f1, 35, Finished, Available, Finished, False)
# ======================================================================
# NEWS INGESTION COMPLETED SUCCESSFULLY
# ======================================================================
# Rows stored: 1835
# Tickers stored: 16
# Output table: financial_news_raw
# Lakehouse: AI_Financial_Lakehouse
